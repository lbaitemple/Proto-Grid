# %% [markdown]
# ## installation for the first time for all python packages

# %%
# %%bash
# sudo pip install jupyterplot
# sudo pip install git+https://github.com/lbaitemple/Proto-Grid.git@dev

# %%
from revidyne import AllDevice

a=AllDevice()
mm=a.getAllDevice()
# Out:
# /dev/ttyUSB1
# /dev/ttyUSB0
# ['/dev/ttyUSB1', '/dev/ttyUSB0']
# Disconnected from /dev/ttyUSB1.
# Disconnected from /dev/ttyUSB0.
# /dev/ttyUSB1
# /dev/ttyUSB0
# fan
# /dev/ttyUSB1
# /dev/ttyUSB0
# ['/dev/ttyUSB1', '/dev/ttyUSB0']
# Disconnected from /dev/ttyUSB1.
# Disconnected from /dev/ttyUSB0.
# fanOn
# fanOff
# autoOn
# autoOff
# setSpeed>1
# getKW<1
# getCarbon<1
# getAll<7
# off
# eoc
# windturbine
# runScan
# trackOn
# trackOff
# goHome
# goL
# goF
# goR
# moveCW>1
# moveCCW>1
# goMax
# lookCW
# lookCCW
# setLoad>1
# setRange>1
# setDelay>1
# setSteps>1
# getMax<1
# getVal<1
# getKW<1
# getAll<7
# getCarbon<1
# getPos<1
# on
# off
# eoc

# %%
st=mm['solartracker'].getDevice()

# %%
st.cmds
# Out:
# {'runScan': <.revidyne.wind.Cmd at 0xffffac15f790>,
#  'trackOn': <.revidyne.wind.Cmd at 0xffffaf32ead0>,
#  'trackOff': <.revidyne.wind.Cmd at 0xffffac15f820>,
#  'goHome': <.revidyne.wind.Cmd at 0xffffac15f8b0>,
#  'goL': <.revidyne.wind.Cmd at 0xffffac15f970>,
#  'goF': <.revidyne.wind.Cmd at 0xffffac15f9d0>,
#  'goR': <.revidyne.wind.Cmd at 0xffffac15fa30>,
#  'moveCW': <.revidyne.wind.Cmd at 0xffffac15f910>,
#  'moveCCW': <.revidyne.wind.Cmd at 0xffffac15fac0>,
#  'goMax': <.revidyne.wind.Cmd at 0xffffac15fb20>,
#  'lookCW': <.revidyne.wind.Cmd at 0xffffac15fa90>,
#  'lookCCW': <.revidyne.wind.Cmd at 0xffffac15fc10>,
#  'setLoad': <.revidyne.wind.Cmd at 0xffffac15fc40>,
#  'setRange': <.revidyne.wind.Cmd at 0xffffac15fbb0>,
#  'setDelay': <.revidyne.wind.Cmd at 0xffffac15fca0>,
#  'setSteps': <.revidyne.wind.Cmd at 0xffffac15fd00>,
#  'getMax': <.revidyne.wind.Cmd at 0xffffac15fd90>,
#  'getVal': <.revidyne.wind.Cmd at 0xffffac15fdc0>,
#  'getKW': <.revidyne.wind.Cmd at 0xffffac15feb0>,
#  'getAll': <.revidyne.wind.Cmd at 0xffffac15fe20>,
#  'getCarbon': <.revidyne.wind.Cmd at 0xffffac15ff70>,
#  'getPos': <.revidyne.wind.Cmd at 0xffffac15fee0>,
#  'on': <.revidyne.wind.Cmd at 0xffffac15ffd0>,
#  'off': <.revidyne.wind.Cmd at 0xffffac15e560>,
#  'eoc': <.revidyne.wind.Cmd at 0xffffac15e500>}

# %%
import ipywidgets.widgets as widgets
from IPython.display import display

# create two sliders with range [-1.0, 1.0]
st_cslider = widgets.IntSlider(description='CW degree', min=0, max=255, step=1, orientation='vertical')
st_ccslider = widgets.IntSlider(description='CCW degree', min=0, max=255, step=1, orientation='vertical')

# create a horizontal box container to place the sliders next to each other
slider_container = widgets.HBox([st_cslider, st_ccslider])

# display the container in this cell's output
display(slider_container)

import traitlets
#from revidyne import windturbine
connect_link = traitlets.link((st_cslider, 'value'), (st, 'cdeg'))
connect_cclink = traitlets.link((st_ccslider, 'value'), (st, 'ccdeg'))
# Out:
# HBox(children=(IntSlider(value=0, description='CW degree', max=255, orientation='vertical'), IntSlider(value=0…

# %%
fan.cmds

# %%
wt = mm['windturbine'].getDevice()

# %%
wt.cmds

# %%
wt.call('trackOn')

# %%
from jupyterplot import ProgressPlot
import numpy as np

pp = ProgressPlot(line_names=["getKW", "getCarbon"])
i=0
while True:
    try:
        a=wt.call("getKW")
        b=wt.call('getCarbon')

    #    pp.update(float(a[0])
        pp.update([[float(a[0]), float(b[0])]])
        i=i+1
    except KeyboardInterrupt:
        print("keyboard interrupt")
        break
        
pp.finalize()

# %%
st = mm['solartracker'].getDevice()

# %%
from jupyterplot import ProgressPlot
import numpy as np

pp = ProgressPlot(line_names=["solar", "carbon", "val"])
i=0
while True:
    try:
        a=st.call("getKW")
        b=st.call('getCarbon')
        c=st.call('getVal')
    #    pp.update(float(a[0])
        pp.update([[float(a[0]), float(b[0]), float(c[0])]])
        i=i+1
    except KeyboardInterrupt:
        print("keyboard interrupt")
        break
        
pp.finalize()
